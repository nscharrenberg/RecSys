# %% [markdown]
# # Group Recommender System

# %% [markdown]
# First import librabries that are needed and read dataset.

# %%
import pandas as pd
import numpy as np

# %%
books_df = pd.read_csv('datasets/valid_only/1/2/books.csv', sep=',', error_bad_lines=False, encoding="cp1252")
users = pd.read_csv('datasets/valid_only/1/2/users.csv', sep=',', error_bad_lines=False, encoding="cp1252")
ratings = pd.read_csv('datasets/valid_only/1/2/ratings.csv', sep=',', error_bad_lines=False, encoding="cp1252")
books_df = books_df.astype({'ISBN': 'string', 'Book-Title': 'string', 'Book-Author': 'string', 'Publisher': 'string', 'Year-Of-Publication': np.uint32})
ratings.columns = ['index', 'ISBN', 'userID', 'bookRating']
books_df.columns = ['index', 'ISBN', 'bookTitle', 'bookAuthor', 'yearOfPublication', 'publisher']

# %%
merged_rows = pd.merge(books_df, ratings, on='ISBN', how='inner')
merged_rows
# Out:
#         index_x        ISBN  \
# 0             0  034545104X
# 1             0  034545104X
# 2             0  034545104X
# 3             0  034545104X
# 4             0  034545104X
# ...         ...         ...
# 220813   220813  0312273150
# 220814   220813  0312273150
# 220815   220815  0679449132
# 220816   220815  0679449132
# 220817   220817  0671015869
#
#                                                 bookTitle          bookAuthor  \
# 0                                    Flesh Tones: A Novel          M. J. Rose
# 1                                    Flesh Tones: A Novel          M. J. Rose
# 2                                    Flesh Tones: A Novel          M. J. Rose
# 3                                    Flesh Tones: A Novel          M. J. Rose
# 4                                    Flesh Tones: A Novel          M. J. Rose
# ...                                                   ...                 ...
# 220813  All About All About Eve: The Complete Behind-T...          Sam Staggs
# 220814  All About All About Eve: The Complete Behind-T...          Sam Staggs
# 220815  Virtuous Reality: How America Surrendered Disc...            Jon Katz
# 220816  Virtuous Reality: How America Surrendered Disc...            Jon Katz
# 220817                             The Surgeon's Daughter  Campbell Armstrong
#
#         yearOfPublication                              publisher  index_y  \
# 0                    2002                       Ballantine Books        0
# 1                    2002                       Ballantine Books        1
# 2                    2002                       Ballantine Books        2
# 3                    2002                       Ballantine Books        3
# 4                    2002                       Ballantine Books        4
# ...                   ...                                    ...      ...
# 220813               2001                     St. Martin's Press   220813
# 220814               2001                     St. Martin's Press   220814
# 220815               1997                           Random House   220815
# 220816               1997                           Random House   220816
# 220817               1999  Simon &amp; Schuster (Trade Division)   220817
#
#         userID  bookRating
# 0         2313           5
# 1        77480           8
# 2        94362           5
# 3        98391           9
# 4       112199           6
# ...        ...         ...
# 220813  272715          10
# 220814  276263           5
# 220815  275383           8
# 220816  275737           5
# 220817  276641           7
#
# [220818 rows x 9 columns]

# %% [markdown]
# Sort the books based on the number of ratings they received

# %%
ratings_most_to_least = ratings.groupby(['ISBN'])['bookRating'].count().reset_index(
  name='Count').sort_values(['Count'], ascending=False)

# %%
ratings_most_to_least
# Out:
#              ISBN  Count
# 61792  0971880107    471
# 11205  0316666343    468
# 22027  0385504209    372
# 8939   0312195516    227
# 39895  059035342X    220
# ...           ...    ...
# 33167  0451524195      1
# 33169  0451524217      1
# 33174  0451524330      1
# 33176  0451524365      1
# 37023  0553246089      1
#
# [74047 rows x 2 columns]

# %% [markdown]
# Take the top N books and remove the rest.

# %%
number_of_books = 15
ratings_most_to_least = ratings_most_to_least.iloc[0:number_of_books , :]

# %%
ratings_most_to_least
# Out:
#              ISBN  Count
# 61792  0971880107    471
# 11205  0316666343    468
# 22027  0385504209    372
# 8939   0312195516    227
# 39895  059035342X    220
# 42383  0671027360    219
# 6652   0142001740    217
# 52814  0786868716    202
# 2124   0060928336    201
# 29913  0446672211    194
# 7195   0156027321    183
# 12472  0345337662    180
# 11275  0316769487    179
# 26215  043935806X    178
# 33730  0452282152    165

# %% [markdown]
# Now remove the ratings that are not needed anymore.

# %%
ratings_only_top = ratings[ratings['ISBN'].isin(ratings_most_to_least['ISBN'])]

# %%
ratings_only_top
# Out:
#        index        ISBN  userID  bookRating
# 507      507  043935806X  278356          10
# 508      508  043935806X    2033           9
# 509      509  043935806X    6251           9
# 510      510  043935806X    6431          10
# 511      511  043935806X    6563          10
# ...      ...         ...     ...         ...
# 30905  30905  0345337662  271367           9
# 30906  30906  0345337662  271538           7
# 30907  30907  0345337662  271558           9
# 30908  30908  0345337662  272573           7
# 30909  30909  0345337662  272626           7
#
# [3676 rows x 4 columns]

# %% [markdown]
# Select users that have rated at least 5 of these selected books. This needs to be done to be able to fill in the missing values, because the table is very sparse.

# %%
count = ratings_only_top['userID'].value_counts()
users_rated_all = ratings_only_top[ratings_only_top['userID'].isin(count[count >= 5].index)]

# %%
users_rated_all
# Out:
#        index        ISBN  userID  bookRating
# 513      513  043935806X   10560          10
# 518      518  043935806X   22625          10
# 566      566  043935806X   95359          10
# 594      594  043935806X  136491           9
# 603      603  043935806X  147141          10
# ...      ...         ...     ...         ...
# 30822  30822  0345337662  136491           9
# 30828  30828  0345337662  147141          10
# 30875  30875  0345337662  229313          10
# 30877  30877  0345337662  229741           7
# 30903  30903  0345337662  270713           6
#
# [85 rows x 4 columns]

# %% [markdown]
# Create dataframe including all the books and users, filling it with all the known and unknown ratings.

# %%
ratings_pivot = users_rated_all.pivot(index='ISBN', columns='userID').bookRating
userID = ratings_pivot.columns
ISBN = ratings_pivot.index
print(ratings_pivot.shape)
ratings_pivot = ratings_pivot.iloc[: , 0:10]
ratings_pivot
# Out:
# (15, 15)
# userID      10560   16795   22625   62862   88693   95359   136491  147141  \
# ISBN
# 0060928336     NaN     NaN     NaN     6.0     NaN     NaN     NaN     7.0
# 0142001740     NaN    10.0     9.0     NaN     NaN     NaN    10.0     NaN
# 0156027321     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 0312195516     9.0     9.0     NaN    10.0     7.0     7.0     NaN     NaN
# 0316666343     8.0    10.0    10.0     6.0     NaN     9.0     NaN     6.0
# 0316769487     NaN     8.0    10.0     NaN     NaN     8.0    10.0     NaN
# 0345337662     NaN     NaN     NaN     NaN     NaN     NaN     9.0    10.0
# 0385504209    10.0    10.0     NaN     NaN     8.0     NaN    10.0     NaN
# 043935806X    10.0     NaN    10.0     NaN     NaN    10.0     9.0    10.0
# 0446672211     NaN     8.0     NaN    10.0     NaN     NaN     NaN     NaN
# 0452282152     NaN     NaN     NaN     NaN     8.0     NaN    10.0     NaN
# 059035342X    10.0     NaN    10.0     NaN     NaN     NaN     NaN     6.0
# 0671027360     8.0     NaN     NaN     8.0     7.0     9.0     NaN     NaN
# 0786868716     NaN     8.0     9.0     NaN     NaN     NaN     NaN     NaN
# 0971880107     NaN     NaN     NaN     NaN     4.0     NaN     NaN     NaN
#
# userID      204864  220688
# ISBN
# 0060928336     9.0     NaN
# 0142001740     NaN     NaN
# 0156027321    10.0     NaN
# 0312195516    10.0     NaN
# 0316666343     9.0     NaN
# 0316769487    10.0     NaN
# 0345337662     NaN     NaN
# 0385504209     NaN    10.0
# 043935806X     NaN    10.0
# 0446672211     NaN     NaN
# 0452282152     NaN    10.0
# 059035342X     NaN    10.0
# 0671027360     NaN     NaN
# 0786868716     NaN     NaN
# 0971880107     NaN     3.0

# %% [markdown]
# Next find the correleation between two users based on the books they have rated using Pearson correlation. If two users give the exact same ratings, the correlation is 1. If the users give opposite ratings, the correlation is -1.

# %%
def find_correlation_between_two_users(ratings_df: pd.DataFrame, user1: str, user2: str):
    rated_books_by_both_users = ratings_df[[user1, user2]].dropna(axis=0).values
    user_1_ratings = rated_books_by_both_users[:, 0]
    user_2_ratings = rated_books_by_both_users[:, 1]
    return np.corrcoef(user_1_ratings, user_2_ratings)[0, 1]

# %% [markdown]
# Using these correlations, build the correlations matrix.

# %%
users = list(ratings_pivot.columns)
books = list(ratings_pivot.index)
similarity_matrix = np.array([[find_correlation_between_two_users(ratings_pivot, user1, user2) for user1 in users] for user2 in users])
similarity_df = pd.DataFrame(similarity_matrix, columns=users, index=users)
# Out:
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\core\_methods.py:180: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\jiska\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
similarity_df
# Out:
#           10560     16795   22625     62862     88693     95359   136491  \
# 10560   1.000000  0.000000     NaN  0.866025  0.866025  0.207514     NaN
# 16795   0.000000  1.000000     0.0 -0.866025  1.000000  0.500000     NaN
# 22625        NaN  0.000000     1.0       NaN       NaN       NaN    -0.5
# 62862   0.866025 -0.866025     NaN  1.000000       NaN -0.866025     NaN
# 88693   0.866025  1.000000     NaN       NaN  1.000000       NaN     NaN
# 95359   0.207514  0.500000     NaN -0.866025       NaN  1.000000    -1.0
# 136491       NaN       NaN    -0.5       NaN       NaN -1.000000     1.0
# 147141  0.500000       NaN     NaN       NaN       NaN  1.000000     NaN
# 204864  1.000000 -0.866025     NaN  1.000000       NaN -0.866025     NaN
# 220688       NaN       NaN     NaN       NaN  1.000000       NaN     NaN
#
#         147141    204864  220688
# 10560      0.5  1.000000     NaN
# 16795      NaN -0.866025     NaN
# 22625      NaN       NaN     NaN
# 62862      NaN  1.000000     NaN
# 88693      NaN       NaN     1.0
# 95359      1.0 -0.866025     NaN
# 136491     NaN       NaN     NaN
# 147141     1.0       NaN     NaN
# 204864     NaN  1.000000     NaN
# 220688     NaN       NaN     1.0

# %% [markdown]
# Next, define some methods that help with predicting the rating a user gives a certain book.

# %%
def get_rated_user_for_a_book(ratings_df: pd.DataFrame, book: str):
    return ratings_df.loc[book, :].dropna().index.values


def get_top_neighbors(
    similarity_df: pd.DataFrame, user: str, rated_users: str, n_neighbors: int
):
    return similarity_df[user][rated_users].nlargest(n_neighbors).to_dict()


def subtract_bias(rating: float, mean_rating: float):
    return rating - mean_rating

# To eleminate bias, subtract rating of the user from the mean rating of the user
def get_neighbor_rating_without_bias_per_book(
    ratings_df: pd.DataFrame, user: str, book: str
):
    mean_rating = ratings_df[user].mean()
    rating = ratings_df.loc[book, user]
    return subtract_bias(rating, mean_rating)


def get_ratings_of_neighbors(ratings_df: pd.DataFrame, neighbors: list, book: str):
    return [
        get_neighbor_rating_without_bias_per_book(ratings_df, neighbor, book)
        for neighbor in neighbors
    ]

def get_weighted_average_rating_of_neighbors(ratings: list, neighbor_distance: list):
    weighted_sum = np.array(ratings).dot(np.array(neighbor_distance))
    abs_neigbor_distance = np.abs(neighbor_distance)
    return weighted_sum / np.sum(abs_neigbor_distance)


def ger_user_rating(ratings_df: pd.DataFrame, user: str, avg_neighbor_rating: float):
    user_avg_rating = ratings_df[user].mean()
    return round(user_avg_rating + avg_neighbor_rating, 2)

# %% [markdown]
# Now, predict the rating of the user for a certain book based on the rating of the neighbors, using the methods defined above.

# %%
def predict_rating(
    df: pd.DataFrame,
    similarity_df: pd.DataFrame,
    user: str,
    book: str,
    n_neighbors: int = 2,
):

    ratings_df = df.copy()

    rated_users = get_rated_user_for_a_book(ratings_df, book)

    top_neighbors_distance = get_top_neighbors(
        similarity_df, user, rated_users, n_neighbors
    )
    neighbors, distance = top_neighbors_distance.keys(), top_neighbors_distance.values()

    ratings = get_ratings_of_neighbors(ratings_df, neighbors, book)
    avg_neighbor_rating = get_weighted_average_rating_of_neighbors(
        ratings, list(distance)
        
    )

    return ger_user_rating(ratings_df, user, avg_neighbor_rating)

# %%
full_ratings = ratings_pivot.copy()

for user, books in full_ratings.iteritems():
    for book in books.keys():
        if np.isnan(full_ratings.loc[book, user]):
            final_rating = predict_rating(
                ratings_pivot, similarity_df, user, book
            )
            if final_rating > 10:
                final_rating = 10
            full_ratings.loc[book, user] = final_rating
# Out:
# <ipython-input-145-5284c65e87cb>:32: RuntimeWarning: invalid value encountered in double_scalars
#   return weighted_sum / np.sum(abs_neigbor_distance)

# %%
full_ratings
# Out:
# userID      10560   16795   22625   62862   88693   95359   136491  147141  \
# ISBN
# 0060928336    7.92   10.00     NaN    6.00     NaN    9.10     NaN    7.00
# 0142001740     NaN   10.00    9.00    7.00    7.80    8.71   10.00     NaN
# 0156027321    9.57    8.60     NaN    8.40     NaN    8.20     NaN     NaN
# 0312195516    9.00    9.00     NaN   10.00    7.00    7.00   10.00    6.68
# 0316666343    8.00   10.00   10.00    6.00    6.79    9.00    9.29    6.00
# 0316769487    9.39    8.00   10.00    8.49    5.80    8.00   10.00    7.20
# 0345337662   10.00     NaN   10.00     NaN     NaN   10.00    9.00   10.00
# 0385504209   10.00   10.00    9.33    7.92    8.00    9.55   10.00    8.63
# 043935806X   10.00   10.00   10.00    7.72    7.94   10.00    9.00   10.00
# 0446672211   10.00    8.00     NaN   10.00    5.80    6.97     NaN     NaN
# 0452282152   10.00   10.00    9.33     NaN    8.00    8.27   10.00     NaN
# 059035342X   10.00     NaN   10.00    8.83    7.94    7.25    9.33    6.00
# 0671027360    8.00    9.27     NaN    8.00    7.00    9.00    9.27    7.68
# 0786868716     NaN    8.00    9.00    9.00    5.80    7.60   10.00     NaN
# 0971880107    6.37    6.20     NaN     NaN    4.00     NaN     NaN     NaN
#
# userID      204864  220688
# ISBN
# 0060928336    9.00     NaN
# 0142001740    8.60     NaN
# 0156027321   10.00     NaN
# 0312195516   10.00     8.8
# 0316666343    9.00     NaN
# 0316769487   10.00     NaN
# 0345337662     NaN     NaN
# 0385504209    9.58    10.0
# 043935806X    9.40    10.0
# 0446672211   10.00     NaN
# 0452282152     NaN    10.0
# 059035342X   10.00    10.0
# 0671027360    9.02     8.8
# 0786868716   10.00     NaN
# 0971880107     NaN     3.0

# %% [markdown]
# Almost the complete table is filled out. If there are missing values, this is because the data is too sparse. Now we can calculate the mean, min and max. To give a recommendation we can order them based on the average rating.

# %%
full_ratings['mean'] = full_ratings.mean(axis=1)
full_ratings['max'] = full_ratings.max(axis=1)
full_ratings['min'] = full_ratings.min(axis=1)
full_ratings['ISBN'] = full_ratings.index
full_ratings['bookTitle'] = full_ratings['ISBN'].map(books_df.set_index('ISBN')['bookTitle'])
full_ratings.sort_values('mean', axis=0, ascending=False)
# Out:
# userID      10560  16795  22625  62862  88693  95359  136491  147141  204864  \
# ISBN
# 0345337662  10.00    NaN  10.00    NaN    NaN  10.00    9.00   10.00     NaN
# 043935806X  10.00  10.00  10.00   7.72   7.94  10.00    9.00   10.00    9.40
# 0452282152  10.00  10.00   9.33    NaN   8.00   8.27   10.00     NaN     NaN
# 0385504209  10.00  10.00   9.33   7.92   8.00   9.55   10.00    8.63    9.58
# 0156027321   9.57   8.60    NaN   8.40    NaN   8.20     NaN     NaN   10.00
# 059035342X  10.00    NaN  10.00   8.83   7.94   7.25    9.33    6.00   10.00
# 0142001740    NaN  10.00   9.00   7.00   7.80   8.71   10.00     NaN    8.60
# 0312195516   9.00   9.00    NaN  10.00   7.00   7.00   10.00    6.68   10.00
# 0316769487   9.39   8.00  10.00   8.49   5.80   8.00   10.00    7.20   10.00
# 0786868716    NaN   8.00   9.00   9.00   5.80   7.60   10.00     NaN   10.00
# 0446672211  10.00   8.00    NaN  10.00   5.80   6.97     NaN     NaN   10.00
# 0671027360   8.00   9.27    NaN   8.00   7.00   9.00    9.27    7.68    9.02
# 0316666343   8.00  10.00  10.00   6.00   6.79   9.00    9.29    6.00    9.00
# 0060928336   7.92  10.00    NaN   6.00    NaN   9.10     NaN    7.00    9.00
# 0971880107   6.37   6.20    NaN    NaN   4.00    NaN     NaN     NaN     NaN
#
# userID      220688      mean    max   min        ISBN  \
# ISBN
# 0345337662     NaN  9.800000  10.00  9.00  0345337662
# 043935806X    10.0  9.406000  10.00  7.72  043935806X
# 0452282152    10.0  9.371429  10.00  8.00  0452282152
# 0385504209    10.0  9.301000  10.00  7.92  0385504209
# 0156027321     NaN  8.954000  10.00  8.20  0156027321
# 059035342X    10.0  8.816667  10.00  6.00  059035342X
# 0142001740     NaN  8.730000  10.00  7.00  0142001740
# 0312195516     8.8  8.608889  10.00  6.68  0312195516
# 0316769487     NaN  8.542222  10.00  5.80  0316769487
# 0786868716     NaN  8.485714  10.00  5.80  0786868716
# 0446672211     NaN  8.461667  10.00  5.80  0446672211
# 0671027360     8.8  8.448889   9.27  7.00  0671027360
# 0316666343     NaN  8.231111  10.00  6.00  0316666343
# 0060928336     NaN  8.170000  10.00  6.00  0060928336
# 0971880107     3.0  4.892500   6.37  3.00  0971880107
#
# userID                                              bookTitle
# ISBN
# 0345337662                         Interview with the Vampire
# 043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 0452282152                          Girl with a Pearl Earring
# 0385504209                                  The Da Vinci Code
# 0156027321                                         Life of Pi
# 059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 0142001740                            The Secret Life of Bees
# 0312195516                The Red Tent (Bestselling Backlist)
# 0316769487                             The Catcher in the Rye
# 0786868716                 The Five People You Meet in Heaven
# 0446672211  Where the Heart Is (Oprah's Book Club (Paperba...
# 0671027360                                Angels &amp; Demons
# 0316666343                          The Lovely Bones: A Novel
# 0060928336    Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 0971880107                                        Wild Animus

# %% [markdown]
# For the least misery method, the books are ordered based on the minimum rating.

# %%
full_ratings.sort_values('min', axis=0, ascending=False)
# Out:
# userID      10560  16795  22625  62862  88693  95359  136491  147141  204864  \
# ISBN
# 0345337662  10.00    NaN  10.00    NaN    NaN  10.00    9.00   10.00     NaN
# 0156027321   9.57   8.60    NaN   8.40    NaN   8.20     NaN     NaN   10.00
# 0452282152  10.00  10.00   9.33    NaN   8.00   8.27   10.00     NaN     NaN
# 0385504209  10.00  10.00   9.33   7.92   8.00   9.55   10.00    8.63    9.58
# 043935806X  10.00  10.00  10.00   7.72   7.94  10.00    9.00   10.00    9.40
# 0142001740    NaN  10.00   9.00   7.00   7.80   8.71   10.00     NaN    8.60
# 0671027360   8.00   9.27    NaN   8.00   7.00   9.00    9.27    7.68    9.02
# 0312195516   9.00   9.00    NaN  10.00   7.00   7.00   10.00    6.68   10.00
# 0060928336   7.92  10.00    NaN   6.00    NaN   9.10     NaN    7.00    9.00
# 0316666343   8.00  10.00  10.00   6.00   6.79   9.00    9.29    6.00    9.00
# 059035342X  10.00    NaN  10.00   8.83   7.94   7.25    9.33    6.00   10.00
# 0316769487   9.39   8.00  10.00   8.49   5.80   8.00   10.00    7.20   10.00
# 0446672211  10.00   8.00    NaN  10.00   5.80   6.97     NaN     NaN   10.00
# 0786868716    NaN   8.00   9.00   9.00   5.80   7.60   10.00     NaN   10.00
# 0971880107   6.37   6.20    NaN    NaN   4.00    NaN     NaN     NaN     NaN
#
# userID      220688      mean    max   min        ISBN  \
# ISBN
# 0345337662     NaN  9.800000  10.00  9.00  0345337662
# 0156027321     NaN  8.954000  10.00  8.20  0156027321
# 0452282152    10.0  9.371429  10.00  8.00  0452282152
# 0385504209    10.0  9.301000  10.00  7.92  0385504209
# 043935806X    10.0  9.406000  10.00  7.72  043935806X
# 0142001740     NaN  8.730000  10.00  7.00  0142001740
# 0671027360     8.8  8.448889   9.27  7.00  0671027360
# 0312195516     8.8  8.608889  10.00  6.68  0312195516
# 0060928336     NaN  8.170000  10.00  6.00  0060928336
# 0316666343     NaN  8.231111  10.00  6.00  0316666343
# 059035342X    10.0  8.816667  10.00  6.00  059035342X
# 0316769487     NaN  8.542222  10.00  5.80  0316769487
# 0446672211     NaN  8.461667  10.00  5.80  0446672211
# 0786868716     NaN  8.485714  10.00  5.80  0786868716
# 0971880107     3.0  4.892500   6.37  3.00  0971880107
#
# userID                                              bookTitle
# ISBN
# 0345337662                         Interview with the Vampire
# 0156027321                                         Life of Pi
# 0452282152                          Girl with a Pearl Earring
# 0385504209                                  The Da Vinci Code
# 043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 0142001740                            The Secret Life of Bees
# 0671027360                                Angels &amp; Demons
# 0312195516                The Red Tent (Bestselling Backlist)
# 0060928336    Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 0316666343                          The Lovely Bones: A Novel
# 059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 0316769487                             The Catcher in the Rye
# 0446672211  Where the Heart Is (Oprah's Book Club (Paperba...
# 0786868716                 The Five People You Meet in Heaven
# 0971880107                                        Wild Animus

# %% [markdown]
# The explanations can be derived from the complete table. The users are anonymous so everyone can see how a certain user rated all the books. By being able to see the mean, maximum and minimum rating of all the books from all users it is clear why a certain recommendation was given.
